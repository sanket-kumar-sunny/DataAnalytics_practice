# %%
import pandas as pd
import numpy as np

# %%
car_sales= pd.read_csv("C:/Sanket.f/My learnings/Udemy/Data science/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data

# %% [markdown]
# #### some tips to use notebook with shortcuts... we can use "escape+m" make cell markdown,

# %% [markdown]
# And also we can use "shift+Enter" to run the cell and move below cell

# %%
#attributes
car_sales.dtypes

#it is function
#car_sales.func() #it runs with several steps
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns= car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe() #it only works on muneric columns
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
# Make             10 non-null object
# Colour           10 non-null object
# Odometer (KM)    10 non-null int64
# Doors            10 non-null int64
# Price            10 non-null object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices= pd.Series([1000,1500,3000])
car_prices.mean()
# Out:
# 1833.3333333333333

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales) #This can be done when one has to analyse few thousand rows in very big files
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # View data and select data in Pandas

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(10) #it gives the quick overview of first 5 data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.tail() #bottom 5
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# loc and iloc

# %%
animals= pd.Series(["cat", "dog", "bird", "panda", "snake"], index=[0, 3, 9, 8,3])
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3] #it refers to index number not range index
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
#print(animals.iloc[3])
print(animals.loc[3])
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'panda'

# %%
#iloc refers to positision,,.... whres loc refers to index

# %% [markdown]
# #through iloc we can do is slicing

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %% [markdown]
# #You see above ... since first method is quiet easy but doent work with column having space

# %%
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"]>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %% [markdown]
# # Selecting and viewing data with Pandas

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %% [markdown]
# As we has seen above.. crosstab is used for comparing two column... but if we want to compare more column then we have to use GROUPBY.

# %%
#Groupby

car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].plot() #it is simply use to plot grah between two column easily

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].hist()

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
# we know that price column is in object format so we have to change price columns in int.

car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales.Price.plot()

# %%
car_sales.Price.hist()

# %% [markdown]
# # Manipulation of data

# %%
car_sales[car_sales["Price"]>100]
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Make"].str.lower() # it lowerr all the string
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales.Make.str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"]= car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales_missing= pd.read_csv("C:/Sanket.f/My learnings/Udemy/Data science/car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.isnull().sum()
# Out:
# Make        1
# Colour      1
# Odometer    4
# Doors       1
# Price       2
# dtype: int64

# %%
car_sales_missing.fillna(car_sales_missing["Odometer"].mean())
# Out:
#       Make   Colour       Odometer         Doors    Price
# 0   Toyota    White  150043.000000      4.000000   $4,000
# 1    Honda      Red   87899.000000      4.000000   $5,000
# 2   Toyota     Blue   92302.666667      3.000000   $7,000
# 3      BMW    Black   11179.000000      5.000000  $22,000
# 4   Nissan    White  213095.000000      4.000000   $3,500
# 5   Toyota    Green   92302.666667      4.000000   $4,500
# 6    Honda  92302.7   92302.666667      4.000000   $7,500
# 7    Honda     Blue   92302.666667      4.000000  92302.7
# 8   Toyota    White   60000.000000  92302.666667  92302.7
# 9  92302.7    White   31600.000000      4.000000   $9,700

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"]= car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing= pd.read_csv("C:/Sanket.f/My learnings/Udemy/Data science/car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped= car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("cars-sales-missing-dropped.csv")

# %%
car_sales_missing_dropped.to_csv("C:/Sanket.f/My learnings/Udemy/Data science/cars-sales-missing-dropped.csv")

# %% [markdown]
# #Column from series # Here we cill create the data

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
#column from series
seats_column=pd.Series([5, 5, 5, 5, 5])

#New column called seats
car_sales["Seats"]= seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    NaN
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_sales["Seats"] = car_sales["Seats"].fillna(car_sales["Seats"].mean())

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    5.0
# 7   honda   Blue          54738      4   700000    5.0
# 8  toyota  White          60000      4   625000    5.0
# 9  nissan  White          31600      4   970000    5.0

# %%
# Column from python list
fuel_economy= [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]
car_sales["Fuel per 100KM"]= fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             3.0
# 9  nissan  White          31600      4   970000    5.0             4.5

# %%
# Now lets check how much fuel is used by cars in their lifetime
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales["Total fuel used"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             3.0
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Total fuel used
# 0            11253.225        11253.225
# 1             8086.708         8086.708
# 2             1627.450         1627.450
# ...

# %%
# Creating the column with single value
car_sales["Number of wheels"]= 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             3.0
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Total fuel used  Number of wheels
# 0            11253.225        11253.225                 4
# 1             8086.708         8086.708                 4
# ...

# %%
car_sales["Passed road safety"] = True

# %%
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                    int32
# Seats                  float64
# Fuel per 100KM         float64
# Total fuel used (L)    float64
# Total fuel used        float64
# Number of wheels         int64
# Passed road safety        bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             3.0
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Total fuel used  Number of wheels  Passed road safety
# 0            11253.225        11253.225                 4                True
# ...

# %%
car_sales= car_sales.drop("Total fuel used", axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             3.0
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road safety
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# ...

# %%
car_sales["Total money spent on fuel (in Rupees)"]= car_sales["Total fuel used (L)"]* 75

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             3.0
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road safety  \
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# ...

# %% [markdown]
# ## Here we know that while modelling we have to randomize that data. there should be no patter in data before modelling

# %% [markdown]
# So here is some technique to randomize and shuffle the data

# %%
car_sales.sample(frac=0.5)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100KM  \
# 1   honda    Red          87899      4  500000    5.0             9.2
# 9  nissan  White          31600      4  970000    5.0             4.5
# 6   honda   Blue          45698      4  750000    5.0             7.6
# 7   honda   Blue          54738      4  700000    5.0             8.7
# 4  nissan  White         213095      4  350000    5.0             8.7
#
#    Total fuel used (L)  Number of wheels  Passed road safety  \
# 1             8086.708                 4                True
# 9             1422.000                 4                True
# 6             3473.048                 4                True
# 7             4762.206                 4                True
# 4            18539.265                 4                True
#
#    Total money spent on fuel (in Rupees)
# 1                             606503.100
# 9                             106650.000
# 6                             260478.600
# ...

# %%
car_sales_shuffled= car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 9  nissan  White          31600      4   970000    5.0             4.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 8  toyota  White          60000      4   625000    5.0             3.0
# 0  toyota  White         150043      4   400000    5.0             7.5
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
#
#    Total fuel used (L)  Number of wheels  Passed road safety  \
# 5             4663.011                 4                True
# 9             1422.000                 4                True
# ...

# %% [markdown]
# #Suppose you have large data set of 2 million rows. So it is become time taking to work on whole data set. So what we can do is we can extract 20% or even 1 % of data for analysis

# %%
car_sales.sample(frac=0.1)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100KM  \
# 2  toyota   Blue          32549      3  700000    5.0             5.0
#
#    Total fuel used (L)  Number of wheels  Passed road safety  \
# 2              1627.45                 4                True
#
#    Total money spent on fuel (in Rupees)
# 2                              122058.75

# %%
car_sales.sample(frac=0.4)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100KM  \
# 2  toyota   Blue          32549      3  700000    5.0             5.0
# 4  nissan  White         213095      4  350000    5.0             8.7
# 1   honda    Red          87899      4  500000    5.0             9.2
# 0  toyota  White         150043      4  400000    5.0             7.5
#
#    Total fuel used (L)  Number of wheels  Passed road safety  \
# 2             1627.450                 4                True
# 4            18539.265                 4                True
# 1             8086.708                 4                True
# 0            11253.225                 4                True
#
#    Total money spent on fuel (in Rupees)
# 2                             122058.750
# 4                            1390444.875
# 1                             606503.100
# 0                             843991.875

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 9  nissan  White          31600      4   970000    5.0             4.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 8  toyota  White          60000      4   625000    5.0             3.0
# 0  toyota  White         150043      4   400000    5.0             7.5
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
#
#    Total fuel used (L)  Number of wheels  Passed road safety  \
# 5             4663.011                 4                True
# 9             1422.000                 4                True
# ...

# %%
car_sales_shuffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0      5  toyota  Green          99213      4   450000    5.0             4.7
# 1      9  nissan  White          31600      4   970000    5.0             4.5
# 2      1   honda    Red          87899      4   500000    5.0             9.2
# 3      8  toyota  White          60000      4   625000    5.0             3.0
# 4      0  toyota  White         150043      4   400000    5.0             7.5
# 5      2  toyota   Blue          32549      3   700000    5.0             5.0
# 6      6   honda   Blue          45698      4   750000    5.0             7.6
# 7      7   honda   Blue          54738      4   700000    5.0             8.7
# 8      3     bmw  Black          11179      5  2200000    5.0             9.6
# 9      4  nissan  White         213095      4   350000    5.0             8.7
#
#    Total fuel used (L)  Number of wheels  Passed road safety  \
# ...

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 9  nissan  White          31600      4   970000    5.0             4.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 8  toyota  White          60000      4   625000    5.0             3.0
# 0  toyota  White         150043      4   400000    5.0             7.5
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
#
#    Total fuel used (L)  Number of wheels  Passed road safety  \
# 5             4663.011                 4                True
# 9             1422.000                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             7.6
# 7   honda   Blue          54738      4   700000    5.0             8.7
# 8  toyota  White          60000      4   625000    5.0             3.0
# 9  nissan  White          31600      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road safety  \
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# ...

# %%
# Working on apply and lamba function

car_sales["Odometer (KM)"]=car_sales["Odometer (KM)"].apply(lambda x:x / 1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White      93776.875      4   400000    5.0             7.5
# 1   honda    Red      54936.875      4   500000    5.0             9.2
# 2  toyota   Blue      20343.125      3   700000    5.0             5.0
# 3     bmw  Black       6986.875      5  2200000    5.0             9.6
# 4  nissan  White     133184.375      4   350000    5.0             8.7
# 5  toyota  Green      62008.125      4   450000    5.0             4.7
# 6   honda   Blue      28561.250      4   750000    5.0             7.6
# 7   honda   Blue      34211.250      4   700000    5.0             8.7
# 8  toyota  White      37500.000      4   625000    5.0             3.0
# 9  nissan  White      19750.000      4   970000    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road safety  \
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# ...

# %%
# Try run your code
# If u dont get.. then search your code
# Try again
# Still stuck then ASK
